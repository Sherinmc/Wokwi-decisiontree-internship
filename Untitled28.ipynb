# %% [markdown]
# <a href="https://colab.research.google.com/github/Sherinmc/Wokwi-decisiontree-internship/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install everywhereml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.6 MB/s eta 0:00:00
# ...
#   Created wheel for everywhereml: filename=everywhereml-0.2.40-py3-none-any.whl size=81188 sha256=4ef9f0fdfaa9839414dc15b2a16a3d31bdd5c44a2e636aa81a09969adc65d48e
#   Stored in directory: /root/.cache/pip/wheels/9f/c0/e7/aa2777ca6fe0c062e0ba46fb79c045cfc22c968df0f4296b8f
# ...
#   Created wheel for hexdump: filename=hexdump-3.3-py3-none-any.whl size=8894 sha256=63db6452cfc47395b405638490c6854f0445f0e7e6576aa3be1fb525a4754d9c
#   Stored in directory: /root/.cache/pip/wheels/5e/b9/b5/227a20e7e8bbdb2b17e46a087c0f0119059ee65fe8374cac18
# Successfully built everywhereml hexdump
# ...

# %%
import  everywhereml

# %%
import everywhereml.sklearn.tree as tree

# %%
print(dir(tree))
# Out:
# ['DecisionTreeClassifier', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %%
from everywhereml.sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(max_depth=2)

# %%
clf.to_arduino_file
# Out:
# <bound method GeneratesCode.to_arduino_file of DecisionTreeClassifier(ccp_alpha=0.0, class_name=DecisionTreeClassifier, class_weight=None, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, monotonic_cst=None, num_outputs=0, package_name=everywhereml.sklearn.tree, random_state=None, splitter=best, template_folder=everywhereml/sklearn/tree)>

# %%
x=[[25,60],[27,65],[29,70],[25,80],[38,85],[40,90]]

# %%
y=[0,0,0,1,1,1]

# %%
clf=DecisionTreeClassifier(max_depth=2)
y=[0,0,0,1,1,1]
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_name=DecisionTreeClassifier, class_weight=None, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, monotonic_cst=None, num_outputs=2, package_name=everywhereml.sklearn.tree, random_state=None, splitter=best, template_folder=everywhereml/sklearn/tree)

# %%
clf.predict([[36]])

# %%
print(clf.predict([[36,82]]))
clf.to_arduino_file('model.h')
# Out:
# [1]
# ...

# %%
print(clf.to_arduino())
# Out:
# #ifndef UUID136414161121552
# #define UUID136414161121552
#
# /**
#   * DecisionTreeClassifier(ccp_alpha=0.0, class_name=DecisionTreeClassifier, class_weight=None, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, monotonic_cst=None, num_outputs=2, package_name=everywhereml.sklearn.tree, random_state=None, splitter=best, template_folder=everywhereml/sklearn/tree)
#  */
# class DecisionTreeClassifier {
#     public:
#
#         /**
#          * Predict class from features
#          */
#         int predict(float *x) {
#             int predictedValue = 0;
#             size_t startedAt = micros();
#
#
#
#
#             if (x[1] < 75.0) {
#
#
#             predictedValue = 0;
#
#
#             }
#             else {
#
#
#             predictedValue = 1;
#
#
#             }
#
#
#
#
#             latency = micros() - startedAt;
#
# ...
